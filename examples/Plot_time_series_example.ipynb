# %% [markdown]
# ### This example shows how to plot time series data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import plot_utils as pu

# %%
# %matplotlib inline

# %% [markdown]
# ### Data: unemployment rate (1976 to 2017)

# %% [markdown]
# Data downloaded from the Bureau of Labor Statistics website (https://www.bls.gov/eag/).

# %%
df = pd.read_csv('./datasets/Unemployment_rate_1976-2017.csv', index_col=0)

# %%
df.head()
# Out:
#           AK   AL   AR    AZ   CA   CO    CT   DC   DE   FL  ...   SD   TN  \
# date                                                         ...
# 1976-01  7.2  6.9  7.6  10.7  9.2  5.5  10.0  9.2  7.1  9.9  ...  3.3  6.2
# 1976-02  7.1  6.7  7.5  10.5  9.1  5.5   9.9  9.1  7.4  9.7  ...  3.2  6.1
# 1976-03  7.1  6.6  7.4  10.2  9.0  5.5   9.8  9.0  7.7  9.5  ...  3.1  6.0
# 1976-04  7.0  6.5  7.3  10.0  9.0  5.5   9.7  8.8  8.1  9.3  ...  3.1  5.9
# 1976-05  7.0  6.4  7.2   9.8  8.9  5.5   9.6  8.7  8.5  9.1  ...  3.0  5.8
#
#           TX   UT   VA   VT   WA   WI   WV   WY
# date
# 1976-01  5.9  6.0  6.0  8.8  8.8  6.0  7.9  4.2
# 1976-02  5.9  5.9  5.9  8.8  8.7  5.9  7.9  4.2
# 1976-03  5.9  5.8  5.9  8.7  8.7  5.7  7.9  4.2
# 1976-04  5.9  5.7  5.8  8.7  8.7  5.6  7.9  4.1
# 1976-05  5.9  5.6  5.8  8.6  8.7  5.5  7.8  4.1
#
# [5 rows x 52 columns]

# %% [markdown]
# ### Plot a single time series: California unemployment rate

# %%
pu.plot_timeseries(df['CA']);  # with all other arguments by default

# %% [markdown]
# ### Single time series with customizable options: Texas unemployment rate, last 10 years only

# %% [markdown]
# With a lot of (but not all) keyword arguments to play with:

# %%
pu.plot_timeseries(
    df.loc['2007-01':,'TX'], 
    date_fmt='%Y-%m', 
    figsize=(14,2), 
    xlabel='Month', 
    ylabel='(Percent)',
    ygrid_on=False, 
    color='orange', 
    lw=4, 
    ls='--', 
    title='Texas unemployment rate',
);

# %% [markdown]
# ### Plot multiple time series using `plot_multiple_timeseries`:

# %%
pu.plot_multiple_timeseries(
    df,
    ylabel='Unemployment rate [%]',
    ncol_legend=10,  # many other keyword arguments can be customized
);

# %% [markdown]
# ### Plot time series with shaded upper/lower bounds

# %% [markdown]
# Simplistically, just use a constant error margin ('2') around CA unemployment rate:

# %%
ub = df['CA'] + 2  # upper bound
lb = df['CA'] - 2  # lower bound

# %%
ub.head()
# Out:
# date
# 1976-01    11.2
# 1976-02    11.1
# 1976-03    11.0
# 1976-04    11.0
# 1976-05    10.9
# Name: CA, dtype: float64

# %%
pu.fill_timeseries(
    df['CA'],
    ub,
    lb,
    color='green',
    ylabel='Unemployment rate [%]',
    title='California',
);

# %% [markdown]
# Note: since plotting error bounds makes the graph more busy, plotting multiple time series (e.g., CA, TX, and MD) with shaded bounds are not encouraged (hence not supported).
